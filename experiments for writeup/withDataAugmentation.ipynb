# %%
# %pip install tensorflow
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install pydot

# %%
from PIL import Image
from pathlib import Path
import os

data_dir = "../hair_types"
image_extensions = [".png", ".jpg", ".jpeg", ".bmp"]


def is_valid_image_pillow(file_name):
    try:
        with Image.open(file_name) as img:
            img.verify()
            if not img.format.lower() in ['png', 'jpeg', 'bmp']:
                print(f"{file_name} is a {img.format}, not accepted by TensorFlow")
                try:
                    os.remove(file_name)
                except Exception as e:
                    print("Failed to remove", file_name, "Error:", str(e))

    except (IOError, SyntaxError) as e:
        print(f"{file_name} is not an image")


for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        is_valid_image_pillow(filepath)
    else:
        print(f"{filepath} not in target extensions")
# Out:
# hair_types\Curly_Hair not in target extensions
# hair_types\Straight_Hair not in target extensions
# hair_types\Wavy_Hair not in target extensions
# hair_types\Curly_Hair\rs_1080x1080-200330130638-1080-ariana-grande-curly-hair-instagram-am-033020.gif not in target extensions

# %%
curly_hair_pics = [label for label in Path(data_dir).rglob("Curly_Hair/*")]
straight_hair_pics = [label for label in Path(
    data_dir).rglob("Straight_Hair/*")]
wavy_hair_pics = [label for label in Path(data_dir).rglob("Wavy_Hair/*")]

# %%
import matplotlib.pyplot as plt
from PIL import Image

img1 = Image.open(str(curly_hair_pics[0]))
img2 = Image.open(str(straight_hair_pics[0]))
img3 = Image.open(str(wavy_hair_pics[0]))

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Curly Hair')

plt.subplot(1, 3, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Straight Hair')

plt.subplot(1, 3, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Wavy Hair')

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (256, 256)
batch_size = 64

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])


def augment_images(image, label):
    image = data_augmentation(image)
    return image, label


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical',
).map(augment_images)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 987 files belonging to 3 classes.
# Using 790 files for training.
# Found 987 files belonging to 3 classes.
# Using 197 files for validation.

# %%
hair_types_labels = [label.replace("_", " ") for label in val_ds.class_names]

# %%
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(hair_types_labels[int(np.argmax(labels[i]))])
        plt.axis("off")
plt.show()

# %%
from keras.models import Sequential

model = Sequential()
model.add(keras.Input(shape=image_size + (3,)))
model.add(layers.Rescaling(1.0/255))

model.add(layers.Conv2D(filters=16, kernel_size=16,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=32, kernel_size=8,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(32))
model.add(layers.Dropout(0.5))
model.add(layers.Activation("relu"))

model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))


# tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_3 (Rescaling)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 121, 121, 16)   │        12,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 121, 121, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 121, 121, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 27, 27, 32)     │        32,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 27, 27, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 27, 27, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 5, 5, 64)       │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 1, 1, 64)       │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 1, 1, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │            99 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,419 (571.95 KB)
#  Trainable params: 146,067 (570.57 KB)
#  Non-trainable params: 352 (1.38 KB)

# %%
epochs = 100

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
history
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 922ms/step - accuracy: 0.3288 - loss: 1.6312 - val_accuracy: 0.2792 - val_loss: 1.1015
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 915ms/step - accuracy: 0.3430 - loss: 1.6105 - val_accuracy: 0.3198 - val_loss: 1.0986
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3512 - loss: 1.5504 - val_accuracy: 0.3299 - val_loss: 1.0956
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3158 - loss: 1.5176 - val_accuracy: 0.3756 - val_loss: 1.1022
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3931 - loss: 1.4473 - val_accuracy: 0.3553 - val_loss: 1.1139
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3926 - loss: 1.4232 - val_accuracy: 0.3655 - val_loss: 1.1224
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3997 - loss: 1.3367 - val_accuracy: 0.3503 - val_loss: 1.1407
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3867 - loss: 1.4538 - val_accuracy: 0.3655 - val_loss: 1.1620
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4159 - loss: 1.3323 - val_accuracy: 0.3350 - val_loss: 1.1833
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3716 - loss: 1.4734 - val_accuracy: 0.4112 - val_loss: 1.2069
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4110 - loss: 1.3759 - val_accuracy: 0.3858 - val_loss: 1.2203
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3855 - loss: 1.3591 - val_accuracy: 0.3959 - val_loss: 1.2319
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4328 - loss: 1.2531 - val_accuracy: 0.4061 - val_loss: 1.2453
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3842 - loss: 1.2867 - val_accuracy: 0.4213 - val_loss: 1.2477
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3643 - loss: 1.3743 - val_accuracy: 0.4213 - val_loss: 1.2459
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4098 - loss: 1.2586 - val_accuracy: 0.4518 - val_loss: 1.2279
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4159 - loss: 1.3005 - val_accuracy: 0.4264 - val_loss: 1.2226
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3887 - loss: 1.2957 - val_accuracy: 0.4315 - val_loss: 1.2057
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3960 - loss: 1.2858 - val_accuracy: 0.4315 - val_loss: 1.2120
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3983 - loss: 1.3033 - val_accuracy: 0.4315 - val_loss: 1.2602
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4222 - loss: 1.2234 - val_accuracy: 0.4061 - val_loss: 1.2908
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4676 - loss: 1.2425 - val_accuracy: 0.4061 - val_loss: 1.2894
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4687 - loss: 1.1218 - val_accuracy: 0.4112 - val_loss: 1.2580
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4340 - loss: 1.2101 - val_accuracy: 0.4315 - val_loss: 1.1955
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4352 - loss: 1.2729 - val_accuracy: 0.4112 - val_loss: 1.1474
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4537 - loss: 1.1715 - val_accuracy: 0.3909 - val_loss: 1.0871
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4576 - loss: 1.1653 - val_accuracy: 0.4365 - val_loss: 1.0574
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4679 - loss: 1.1712 - val_accuracy: 0.4619 - val_loss: 1.0851
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4374 - loss: 1.1986 - val_accuracy: 0.4518 - val_loss: 1.1524
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4680 - loss: 1.1205 - val_accuracy: 0.4772 - val_loss: 1.1017
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4613 - loss: 1.1076 - val_accuracy: 0.5482 - val_loss: 0.9945
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4663 - loss: 1.1364 - val_accuracy: 0.5228 - val_loss: 1.0119
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4890 - loss: 1.1184 - val_accuracy: 0.5431 - val_loss: 1.0063
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4558 - loss: 1.1030 - val_accuracy: 0.5279 - val_loss: 0.9593
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4492 - loss: 1.1355 - val_accuracy: 0.5127 - val_loss: 0.9595
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4381 - loss: 1.1674 - val_accuracy: 0.5127 - val_loss: 0.9506
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4895 - loss: 1.0841 - val_accuracy: 0.5178 - val_loss: 0.9564
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4306 - loss: 1.1651 - val_accuracy: 0.5228 - val_loss: 1.0135
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5056 - loss: 1.0640 - val_accuracy: 0.5025 - val_loss: 0.9747
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4780 - loss: 1.0689 - val_accuracy: 0.5025 - val_loss: 1.0119
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4574 - loss: 1.1000 - val_accuracy: 0.4975 - val_loss: 1.0790
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4859 - loss: 1.0457 - val_accuracy: 0.5178 - val_loss: 1.0859
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4611 - loss: 1.0624 - val_accuracy: 0.5178 - val_loss: 1.0534
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4826 - loss: 1.0436 - val_accuracy: 0.5076 - val_loss: 1.0449
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4834 - loss: 1.0803 - val_accuracy: 0.5127 - val_loss: 1.0520
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4810 - loss: 1.0684 - val_accuracy: 0.4924 - val_loss: 1.0394
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4632 - loss: 1.0917 - val_accuracy: 0.5431 - val_loss: 1.0325
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4927 - loss: 1.0585 - val_accuracy: 0.5431 - val_loss: 1.0032
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4727 - loss: 1.0662 - val_accuracy: 0.5076 - val_loss: 1.0228
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5001 - loss: 1.0257 - val_accuracy: 0.5584 - val_loss: 0.9399
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4943 - loss: 1.0300 - val_accuracy: 0.5076 - val_loss: 0.9323
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4852 - loss: 1.1126 - val_accuracy: 0.4670 - val_loss: 1.0352
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5215 - loss: 1.0209 - val_accuracy: 0.4924 - val_loss: 1.0012
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4941 - loss: 1.0605 - val_accuracy: 0.5076 - val_loss: 1.0203
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4925 - loss: 1.0709 - val_accuracy: 0.5381 - val_loss: 0.9517
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5212 - loss: 1.0096 - val_accuracy: 0.5584 - val_loss: 0.9322
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4925 - loss: 1.0240 - val_accuracy: 0.5685 - val_loss: 0.9119
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5030 - loss: 1.0081 - val_accuracy: 0.5178 - val_loss: 0.9994
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5079 - loss: 1.0504 - val_accuracy: 0.4975 - val_loss: 1.0598
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5334 - loss: 0.9718 - val_accuracy: 0.4721 - val_loss: 1.0429
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4920 - loss: 1.0521 - val_accuracy: 0.5178 - val_loss: 0.9515
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5425 - loss: 0.9673 - val_accuracy: 0.4619 - val_loss: 1.0565
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4820 - loss: 1.0007 - val_accuracy: 0.5736 - val_loss: 0.8975
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4879 - loss: 1.0138 - val_accuracy: 0.5736 - val_loss: 0.9133
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4950 - loss: 1.0256 - val_accuracy: 0.5431 - val_loss: 0.9845
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4836 - loss: 1.0263 - val_accuracy: 0.5025 - val_loss: 1.0010
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5314 - loss: 1.0101 - val_accuracy: 0.3604 - val_loss: 1.2721
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4790 - loss: 1.0349 - val_accuracy: 0.3655 - val_loss: 1.3074
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5008 - loss: 1.0161 - val_accuracy: 0.4416 - val_loss: 1.0855
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5106 - loss: 1.0032 - val_accuracy: 0.5533 - val_loss: 0.9334
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5526 - loss: 0.9424 - val_accuracy: 0.2843 - val_loss: 2.5992
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5443 - loss: 0.9982 - val_accuracy: 0.2843 - val_loss: 2.2907
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5207 - loss: 0.9820 - val_accuracy: 0.4315 - val_loss: 1.1217
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5157 - loss: 0.9368 - val_accuracy: 0.5178 - val_loss: 0.9754
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5397 - loss: 0.9338 - val_accuracy: 0.4924 - val_loss: 1.1030
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4953 - loss: 1.0173 - val_accuracy: 0.5076 - val_loss: 1.0028
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4961 - loss: 0.9868 - val_accuracy: 0.5838 - val_loss: 0.8973
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5379 - loss: 0.9773 - val_accuracy: 0.5431 - val_loss: 0.9757
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5297 - loss: 0.9569 - val_accuracy: 0.5990 - val_loss: 0.8764
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4987 - loss: 1.0127 - val_accuracy: 0.5888 - val_loss: 0.9119
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4829 - loss: 1.0248 - val_accuracy: 0.5381 - val_loss: 1.0840
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5222 - loss: 0.9485 - val_accuracy: 0.5431 - val_loss: 1.0357
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5358 - loss: 0.9434 - val_accuracy: 0.5279 - val_loss: 0.9543
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5049 - loss: 1.0179 - val_accuracy: 0.5178 - val_loss: 1.0147
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4974 - loss: 1.0025 - val_accuracy: 0.5584 - val_loss: 0.8899
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5502 - loss: 0.9374 - val_accuracy: 0.5025 - val_loss: 1.0023
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5185 - loss: 0.9839 - val_accuracy: 0.5635 - val_loss: 0.9322
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5073 - loss: 0.9777 - val_accuracy: 0.5635 - val_loss: 0.8963
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5411 - loss: 0.9630 - val_accuracy: 0.5381 - val_loss: 0.9526
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4932 - loss: 0.9969 - val_accuracy: 0.5888 - val_loss: 0.9038
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5458 - loss: 0.9472 - val_accuracy: 0.5736 - val_loss: 0.8780
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5373 - loss: 0.9566 - val_accuracy: 0.5685 - val_loss: 0.9062
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5437 - loss: 0.9530 - val_accuracy: 0.6041 - val_loss: 0.8647
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5289 - loss: 0.9655 - val_accuracy: 0.5838 - val_loss: 0.9209
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4978 - loss: 0.9526 - val_accuracy: 0.5279 - val_loss: 0.9816
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5652 - loss: 0.9129 - val_accuracy: 0.5838 - val_loss: 0.8673
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5374 - loss: 0.9532 - val_accuracy: 0.5838 - val_loss: 0.8886
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5408 - loss: 0.9345 - val_accuracy: 0.5736 - val_loss: 0.8687
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5437 - loss: 0.9040 - val_accuracy: 0.5838 - val_loss: 0.8689
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5119 - loss: 0.9379 - val_accuracy: 0.5736 - val_loss: 0.8846

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np

true_labels = []
pred_labels = []

for images, labels in val_ds:
    true_labels.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images)
    pred_labels.extend(np.argmax(preds, axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000016E9F8F2B60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

hair_labels_cm = ['Curly Hair', 'Straight Hair', 'Wavy Hair']

cm = confusion_matrix(true_labels, pred_labels)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=hair_labels_cm).plot(
    include_values=True, cmap='Blues', colorbar=False)

# %%
from sklearn.metrics import classification_report
import pandas as pd

class_report = classification_report(
    true_labels, pred_labels, target_names=hair_types_labels, output_dict=True)
report_df = pd.DataFrame(class_report).transpose()

report_df = report_df.drop(index=['accuracy', 'macro avg', 'weighted avg'])
report_df = report_df.round(2)

report_df
# Out:
#                precision  recall  f1-score  support
# Curly Hair          0.54    0.79      0.64     56.0
# Straight Hair       0.64    0.49      0.55     70.0
# Wavy Hair           0.56    0.49      0.53     71.0

# %%
img_array = keras.preprocessing.image.img_to_array(img3)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)

plt.axis("off")
plt.imshow(img3)
# Out:
# WARNING:tensorflow:6 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000016E9F8F2B60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# This image is 0.20 percent curly hair, 0.41 percent straight hair, and 0.40 percent wavy hair.
