# %%
# %pip install tensorflow
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install pydot

# %%
from PIL import Image
from pathlib import Path
import os

data_dir = "../hair_types"
image_extensions = [".png", ".jpg", ".jpeg", ".bmp"]


def is_valid_image_pillow(file_name):
    try:
        with Image.open(file_name) as img:
            img.verify()
            if not img.format.lower() in ['png', 'jpeg', 'bmp']:
                print(f"{file_name} is a {img.format}, not accepted by TensorFlow")
                try:
                    os.remove(file_name)
                except Exception as e:
                    print("Failed to remove", file_name, "Error:", str(e))

    except (IOError, SyntaxError) as e:
        print(f"{file_name} is not an image")


for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        is_valid_image_pillow(filepath)
    else:
        print(f"{filepath} not in target extensions")
# Out:
# ..\hair_types\Curly_Hair not in target extensions
# ..\hair_types\Straight_Hair not in target extensions
# ..\hair_types\Wavy_Hair not in target extensions
# ..\hair_types\Curly_Hair\rs_1080x1080-200330130638-1080-ariana-grande-curly-hair-instagram-am-033020.gif not in target extensions

# %%
curly_hair_pics = [label for label in Path(data_dir).rglob("Curly_Hair/*")]
straight_hair_pics = [label for label in Path(
    data_dir).rglob("Straight_Hair/*")]
wavy_hair_pics = [label for label in Path(data_dir).rglob("Wavy_Hair/*")]

# %%
import matplotlib.pyplot as plt
from PIL import Image

img1 = Image.open(str(curly_hair_pics[0]))
img2 = Image.open(str(straight_hair_pics[0]))
img3 = Image.open(str(wavy_hair_pics[0]))

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Curly Hair')

plt.subplot(1, 3, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Straight Hair')

plt.subplot(1, 3, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Wavy Hair')

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (256, 256)
batch_size = 64

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])


def augment_images(image, label):
    image = data_augmentation(image)
    return image, label


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical',
).map(augment_images)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 987 files belonging to 3 classes.
# Using 790 files for training.
# Found 987 files belonging to 3 classes.
# Using 197 files for validation.

# %%
hair_types_labels = [label.replace("_", " ") for label in val_ds.class_names]

# %%
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(hair_types_labels[int(np.argmax(labels[i]))])
        plt.axis("off")
plt.show()

# %%
from keras.models import Sequential

model = Sequential()
model.add(keras.Input(shape=image_size + (3,)))
model.add(layers.Rescaling(1.0/255))

model.add(layers.Conv2D(filters=16, kernel_size=16,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=32, kernel_size=8,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(32))
model.add(layers.Dropout(0.5))
model.add(layers.Activation("relu"))

model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))


# tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 121, 121, 16)   │        12,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 121, 121, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 121, 121, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 27, 27, 32)     │        32,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 27, 27, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 27, 27, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 5, 5, 64)       │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 1, 1, 64)       │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1, 1, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,419 (571.95 KB)
#  Trainable params: 146,067 (570.57 KB)
#  Non-trainable params: 352 (1.38 KB)

# %%
epochs = 50

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
history
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 16s 898ms/step - accuracy: 0.3580 - loss: 1.7037 - val_accuracy: 0.2132 - val_loss: 1.1065
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3836 - loss: 1.6577 - val_accuracy: 0.2995 - val_loss: 1.1071
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3807 - loss: 1.6067 - val_accuracy: 0.3604 - val_loss: 1.1047
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.3652 - loss: 1.7324 - val_accuracy: 0.3604 - val_loss: 1.1089
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 813ms/step - accuracy: 0.3298 - loss: 1.7556 - val_accuracy: 0.3604 - val_loss: 1.1131
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.3835 - loss: 1.5931 - val_accuracy: 0.3604 - val_loss: 1.1193
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4080 - loss: 1.4894 - val_accuracy: 0.3604 - val_loss: 1.1290
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.3921 - loss: 1.5294 - val_accuracy: 0.3604 - val_loss: 1.1393
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.3773 - loss: 1.5233 - val_accuracy: 0.3604 - val_loss: 1.1380
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3978 - loss: 1.5360 - val_accuracy: 0.3604 - val_loss: 1.1432
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3760 - loss: 1.4384 - val_accuracy: 0.3604 - val_loss: 1.1474
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.3943 - loss: 1.4117 - val_accuracy: 0.3604 - val_loss: 1.1643
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3838 - loss: 1.4591 - val_accuracy: 0.3756 - val_loss: 1.1611
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4026 - loss: 1.4215 - val_accuracy: 0.3756 - val_loss: 1.1581
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.4251 - loss: 1.2866 - val_accuracy: 0.3858 - val_loss: 1.1285
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.3966 - loss: 1.4226 - val_accuracy: 0.3858 - val_loss: 1.1193
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4161 - loss: 1.3883 - val_accuracy: 0.3909 - val_loss: 1.1271
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4130 - loss: 1.2767 - val_accuracy: 0.4010 - val_loss: 1.1389
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 884ms/step - accuracy: 0.3874 - loss: 1.4022 - val_accuracy: 0.4010 - val_loss: 1.1412
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.3894 - loss: 1.3947 - val_accuracy: 0.4010 - val_loss: 1.1273
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4505 - loss: 1.2490 - val_accuracy: 0.4112 - val_loss: 1.1481
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4278 - loss: 1.2465 - val_accuracy: 0.4162 - val_loss: 1.1429
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4135 - loss: 1.2523 - val_accuracy: 0.4061 - val_loss: 1.1386
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3859 - loss: 1.2621 - val_accuracy: 0.4569 - val_loss: 1.1186
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4072 - loss: 1.2267 - val_accuracy: 0.4619 - val_loss: 1.1047
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4301 - loss: 1.2149 - val_accuracy: 0.4619 - val_loss: 1.0956
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4554 - loss: 1.2109 - val_accuracy: 0.4518 - val_loss: 1.0840
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4315 - loss: 1.2724 - val_accuracy: 0.4822 - val_loss: 1.0415
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4235 - loss: 1.2208 - val_accuracy: 0.4975 - val_loss: 1.0237
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4418 - loss: 1.1876 - val_accuracy: 0.5178 - val_loss: 1.0163
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4482 - loss: 1.1720 - val_accuracy: 0.5127 - val_loss: 1.0063
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4726 - loss: 1.1796 - val_accuracy: 0.5076 - val_loss: 1.0009
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.4611 - loss: 1.1822 - val_accuracy: 0.5127 - val_loss: 1.0047
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4427 - loss: 1.1844 - val_accuracy: 0.5330 - val_loss: 1.0043
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.4797 - loss: 1.1194 - val_accuracy: 0.5482 - val_loss: 1.0034
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4375 - loss: 1.1376 - val_accuracy: 0.5381 - val_loss: 1.0077
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4085 - loss: 1.2086 - val_accuracy: 0.5330 - val_loss: 1.0043
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4676 - loss: 1.1448 - val_accuracy: 0.5533 - val_loss: 1.0026
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4313 - loss: 1.1204 - val_accuracy: 0.5482 - val_loss: 0.9964
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4439 - loss: 1.1461 - val_accuracy: 0.5381 - val_loss: 0.9806
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4491 - loss: 1.1318 - val_accuracy: 0.5482 - val_loss: 0.9816
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4263 - loss: 1.1496 - val_accuracy: 0.5381 - val_loss: 0.9920
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4880 - loss: 1.0299 - val_accuracy: 0.5381 - val_loss: 1.0022
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4376 - loss: 1.1471 - val_accuracy: 0.5381 - val_loss: 1.0030
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4759 - loss: 1.0991 - val_accuracy: 0.5381 - val_loss: 0.9955
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4508 - loss: 1.1471 - val_accuracy: 0.5635 - val_loss: 0.9982
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4451 - loss: 1.1318 - val_accuracy: 0.5787 - val_loss: 0.9954
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5113 - loss: 1.0616 - val_accuracy: 0.5482 - val_loss: 0.9900
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4094 - loss: 1.1362 - val_accuracy: 0.5685 - val_loss: 0.9859
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.4311 - loss: 1.0880 - val_accuracy: 0.5431 - val_loss: 0.9833

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np

true_labels = []
pred_labels = []

for images, labels in val_ds:
    true_labels.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images)
    pred_labels.extend(np.argmax(preds, axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

hair_labels_cm = ['Curly Hair', 'Straight Hair', 'Wavy Hair']

cm = confusion_matrix(true_labels, pred_labels)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=hair_labels_cm).plot(
    include_values=True, cmap='Blues', colorbar=False)

# %%
from sklearn.metrics import classification_report
import pandas as pd

class_report = classification_report(
    true_labels, pred_labels, target_names=hair_types_labels, output_dict=True)
report_df = pd.DataFrame(class_report).transpose()

report_df = report_df.drop(index=['accuracy', 'macro avg', 'weighted avg'])
report_df = report_df.round(2)

report_df
# Out:
#                precision  recall  f1-score  support
# Curly Hair          0.56    0.50      0.53     56.0
# Straight Hair       0.53    0.57      0.55     70.0
# Wavy Hair           0.55    0.55      0.55     71.0

# %%
img_array = keras.preprocessing.image.img_to_array(img3)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)

plt.axis("off")
plt.imshow(img3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# This image is 0.22 percent curly hair, 0.46 percent straight hair, and 0.32 percent wavy hair.
