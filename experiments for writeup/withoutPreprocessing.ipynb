# %%
# %pip install tensorflow
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install pydot

# %%
from PIL import Image
from pathlib import Path
import os

data_dir = "../hair_types"
image_extensions = [".png", ".jpg", ".jpeg", ".bmp"]


def is_valid_image_pillow(file_name):
    try:
        with Image.open(file_name) as img:
            img.verify()
            if not img.format.lower() in ['png', 'jpeg', 'bmp']:
                print(f"{file_name} is a {img.format}, not accepted by TensorFlow")
                try:
                    os.remove(file_name)
                except Exception as e:
                    print("Failed to remove", file_name, "Error:", str(e))

    except (IOError, SyntaxError) as e:
        print(f"{file_name} is not an image")


for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        is_valid_image_pillow(filepath)
    else:
        print(f"{filepath} not in target extensions")
# Out:
# ..\hair_types\Curly_Hair not in target extensions
# ..\hair_types\Straight_Hair not in target extensions
# ..\hair_types\Wavy_Hair not in target extensions
# ..\hair_types\Curly_Hair\rs_1080x1080-200330130638-1080-ariana-grande-curly-hair-instagram-am-033020.gif not in target extensions

# %%
curly_hair_pics = [label for label in Path(data_dir).rglob("Curly_Hair/*")]
straight_hair_pics = [label for label in Path(
    data_dir).rglob("Straight_Hair/*")]
wavy_hair_pics = [label for label in Path(data_dir).rglob("Wavy_Hair/*")]

# %%
import matplotlib.pyplot as plt
from PIL import Image

img1 = Image.open(str(curly_hair_pics[0]))
img2 = Image.open(str(straight_hair_pics[0]))
img3 = Image.open(str(wavy_hair_pics[0]))

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Curly Hair')

plt.subplot(1, 3, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Straight Hair')

plt.subplot(1, 3, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Wavy Hair')

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (256, 256)
batch_size = 64

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical',
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 987 files belonging to 3 classes.
# Using 790 files for training.
# Found 987 files belonging to 3 classes.
# Using 197 files for validation.

# %%
hair_types_labels = [label.replace("_", " ") for label in val_ds.class_names]

# %%
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(hair_types_labels[int(np.argmax(labels[i]))])
        plt.axis("off")
plt.show()

# %%
from keras.models import Sequential

model = Sequential()
model.add(keras.Input(shape=image_size + (3,)))
model.add(layers.Rescaling(1.0/255))

model.add(layers.Conv2D(filters=16, kernel_size=16,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=32, kernel_size=8,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(32))
model.add(layers.Dropout(0.5))
model.add(layers.Activation("relu"))

model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))


# tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 121, 121, 16)   │        12,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 121, 121, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 121, 121, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 27, 27, 32)     │        32,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 27, 27, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 27, 27, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 5, 5, 64)       │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 1, 1, 64)       │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1, 1, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            99 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,419 (571.95 KB)
#  Trainable params: 146,067 (570.57 KB)
#  Non-trainable params: 352 (1.38 KB)

# %%
epochs = 50

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
history
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.3013 - loss: 1.7828 - val_accuracy: 0.3604 - val_loss: 1.0944
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 667ms/step - accuracy: 0.3681 - loss: 1.4746 - val_accuracy: 0.3706 - val_loss: 1.0928
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 604ms/step - accuracy: 0.3537 - loss: 1.5863 - val_accuracy: 0.3706 - val_loss: 1.0930
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 610ms/step - accuracy: 0.3318 - loss: 1.5786 - val_accuracy: 0.3553 - val_loss: 1.1026
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 804ms/step - accuracy: 0.3579 - loss: 1.4479 - val_accuracy: 0.3553 - val_loss: 1.1186
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 809ms/step - accuracy: 0.3942 - loss: 1.4077 - val_accuracy: 0.3553 - val_loss: 1.1431
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 643ms/step - accuracy: 0.4245 - loss: 1.3274 - val_accuracy: 0.3553 - val_loss: 1.1842
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 619ms/step - accuracy: 0.4260 - loss: 1.3408 - val_accuracy: 0.3553 - val_loss: 1.2182
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 824ms/step - accuracy: 0.4415 - loss: 1.2738 - val_accuracy: 0.3553 - val_loss: 1.2507
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 838ms/step - accuracy: 0.4303 - loss: 1.2975 - val_accuracy: 0.3553 - val_loss: 1.2794
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 834ms/step - accuracy: 0.4465 - loss: 1.2224 - val_accuracy: 0.3553 - val_loss: 1.3331
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 842ms/step - accuracy: 0.4483 - loss: 1.1957 - val_accuracy: 0.3553 - val_loss: 1.3827
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 874ms/step - accuracy: 0.4658 - loss: 1.2299 - val_accuracy: 0.3553 - val_loss: 1.4112
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 830ms/step - accuracy: 0.4476 - loss: 1.2377 - val_accuracy: 0.3553 - val_loss: 1.4407
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 594ms/step - accuracy: 0.4586 - loss: 1.1634 - val_accuracy: 0.3553 - val_loss: 1.4663
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 791ms/step - accuracy: 0.4660 - loss: 1.1824 - val_accuracy: 0.3503 - val_loss: 1.4813
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 787ms/step - accuracy: 0.4427 - loss: 1.2631 - val_accuracy: 0.3553 - val_loss: 1.5048
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 791ms/step - accuracy: 0.5079 - loss: 1.1139 - val_accuracy: 0.3553 - val_loss: 1.5167
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 789ms/step - accuracy: 0.4815 - loss: 1.1606 - val_accuracy: 0.3553 - val_loss: 1.4980
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 798ms/step - accuracy: 0.5081 - loss: 1.1483 - val_accuracy: 0.3604 - val_loss: 1.4962
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 791ms/step - accuracy: 0.4911 - loss: 1.0475 - val_accuracy: 0.3655 - val_loss: 1.4650
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 597ms/step - accuracy: 0.5091 - loss: 1.0480 - val_accuracy: 0.3858 - val_loss: 1.3944
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 596ms/step - accuracy: 0.5216 - loss: 1.0734 - val_accuracy: 0.3807 - val_loss: 1.3946
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 596ms/step - accuracy: 0.5491 - loss: 1.0015 - val_accuracy: 0.3959 - val_loss: 1.3561
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 601ms/step - accuracy: 0.5061 - loss: 1.0137 - val_accuracy: 0.4112 - val_loss: 1.2909
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 600ms/step - accuracy: 0.5199 - loss: 1.0547 - val_accuracy: 0.4112 - val_loss: 1.3470
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 607ms/step - accuracy: 0.5313 - loss: 0.9714 - val_accuracy: 0.4162 - val_loss: 1.3476
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 606ms/step - accuracy: 0.5505 - loss: 0.9577 - val_accuracy: 0.4213 - val_loss: 1.2751
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 608ms/step - accuracy: 0.5913 - loss: 0.9404 - val_accuracy: 0.4518 - val_loss: 1.2277
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 613ms/step - accuracy: 0.5659 - loss: 0.9472 - val_accuracy: 0.4873 - val_loss: 1.2047
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 668ms/step - accuracy: 0.5566 - loss: 0.9253 - val_accuracy: 0.4772 - val_loss: 1.1445
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 641ms/step - accuracy: 0.5643 - loss: 0.9088 - val_accuracy: 0.4975 - val_loss: 1.1357
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.5294 - loss: 0.9434 - val_accuracy: 0.4873 - val_loss: 1.1458
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 657ms/step - accuracy: 0.5638 - loss: 0.9338 - val_accuracy: 0.4721 - val_loss: 1.1049
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 660ms/step - accuracy: 0.5718 - loss: 0.9195 - val_accuracy: 0.5127 - val_loss: 1.0779
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 688ms/step - accuracy: 0.5925 - loss: 0.8643 - val_accuracy: 0.5025 - val_loss: 1.0555
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 656ms/step - accuracy: 0.5862 - loss: 0.8910 - val_accuracy: 0.5025 - val_loss: 1.0591
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.5895 - loss: 0.8795 - val_accuracy: 0.4822 - val_loss: 1.1225
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 660ms/step - accuracy: 0.5714 - loss: 0.9307 - val_accuracy: 0.4822 - val_loss: 1.1117
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 664ms/step - accuracy: 0.5863 - loss: 0.8636 - val_accuracy: 0.5279 - val_loss: 0.9927
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 694ms/step - accuracy: 0.5512 - loss: 0.9262 - val_accuracy: 0.5330 - val_loss: 0.9692
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 688ms/step - accuracy: 0.6351 - loss: 0.7933 - val_accuracy: 0.5228 - val_loss: 1.0412
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 659ms/step - accuracy: 0.5933 - loss: 0.8679 - val_accuracy: 0.5178 - val_loss: 1.0294
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 659ms/step - accuracy: 0.6143 - loss: 0.8291 - val_accuracy: 0.5533 - val_loss: 0.9281
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 665ms/step - accuracy: 0.6088 - loss: 0.8186 - val_accuracy: 0.5533 - val_loss: 0.9229
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 692ms/step - accuracy: 0.5807 - loss: 0.8713 - val_accuracy: 0.5228 - val_loss: 0.9498
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 682ms/step - accuracy: 0.5847 - loss: 0.8375 - val_accuracy: 0.5279 - val_loss: 1.0047
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 662ms/step - accuracy: 0.6501 - loss: 0.7492 - val_accuracy: 0.5330 - val_loss: 0.9865
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 616ms/step - accuracy: 0.6414 - loss: 0.7688 - val_accuracy: 0.5533 - val_loss: 0.9949
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 604ms/step - accuracy: 0.6392 - loss: 0.7715 - val_accuracy: 0.5431 - val_loss: 0.9983

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np

true_labels = []
pred_labels = []

for images, labels in val_ds:
    true_labels.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images)
    pred_labels.extend(np.argmax(preds, axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

hair_labels_cm = ['Curly Hair', 'Straight Hair', 'Wavy Hair']

cm = confusion_matrix(true_labels, pred_labels)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=hair_labels_cm).plot(
    include_values=True, cmap='Blues', colorbar=False)

# %%
from sklearn.metrics import classification_report
import pandas as pd

class_report = classification_report(
    true_labels, pred_labels, target_names=hair_types_labels, output_dict=True)
report_df = pd.DataFrame(class_report).transpose()

report_df = report_df.drop(index=['accuracy', 'macro avg', 'weighted avg'])
report_df = report_df.round(2)

report_df
# Out:
#                precision  recall  f1-score  support
# Curly Hair          0.76    0.29      0.42     56.0
# Straight Hair       0.58    0.57      0.58     70.0
# Wavy Hair           0.48    0.72      0.57     71.0

# %%
img_array = keras.preprocessing.image.img_to_array(img3)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)

plt.axis("off")
plt.imshow(img3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# This image is 0.07 percent curly hair, 0.50 percent straight hair, and 0.42 percent wavy hair.
