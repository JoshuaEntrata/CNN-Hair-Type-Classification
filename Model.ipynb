# %%
# %pip install tensorflow
# %pip install numpy
# %pip install pandas
# %pip install matplotlib

# %%
from PIL import Image
from pathlib import Path
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg", ".jpeg", ".bmp"]


def is_valid_image_pillow(file_name):
    try:
        with Image.open(file_name) as img:
            img.verify()
            img = Image.open(file_name)
            if not img.format.lower() in ['png', 'jpeg', 'bmp']:
                print(f"{file_name} is a {img.format}, not accepted by TensorFlow")
                os.remove(file_name)

    except (IOError, SyntaxError) as e:
        print(f"{file_name} is not an image")


for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        is_valid_image_pillow(filepath)
    else:
        print(f"{filepath} not in target extensions")
# Out:
# hair_types\Curly_Hair not in target extensions
# hair_types\Straight_Hair not in target extensions
# hair_types\Wavy_Hair not in target extensions
# hair_types\Curly_Hair\rs_1080x1080-200330130638-1080-ariana-grande-curly-hair-instagram-am-033020.gif not in target extensions

# %%
curly_hair_pics = [label for label in Path(data_dir).rglob("Curly_Hair/*")]
straight_hair_pics = [label for label in Path(
    data_dir).rglob("Straight_Hair/*")]
wavy_hair_pics = [label for label in Path(data_dir).rglob("Wavy_Hair/*")]

# %%
import matplotlib.pyplot as plt
from PIL import Image

img1 = Image.open(str(curly_hair_pics[0]))
img2 = Image.open(str(straight_hair_pics[0]))
img3 = Image.open(str(wavy_hair_pics[0]))

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Curly Hair')

plt.subplot(1, 3, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Straight Hair')

plt.subplot(1, 3, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Wavy Hair')

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (64, 64)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="training",
    seed=132,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=132,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 987 files belonging to 3 classes.
# Using 790 files for training.
# Found 987 files belonging to 3 classes.
# Using 197 files for validation.

# %%
hair_types_labels = [label.replace("_", " ") for label in train_ds.class_names]

# %%
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(hair_types_labels[int(np.argmax(labels[i]))])
        plt.axis("off")
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(keras.Input(shape=image_size + (3,)))
model.add(layers.Rescaling(1.0 / 255))

model.add(layers.Conv2D(filters=16, kernel_size=3,
          strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D())
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(filters=32, kernel_size=3,
          strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D())
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(filters=64, kernel_size=3,
          strides=1, padding='valid', dilation_rate=1))
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D())
model.add(layers.Dropout(0.2))

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))
model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)         │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 62, 62, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 62, 62, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 31, 31, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 29, 29, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 29, 29, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           195 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,939 (109.14 KB)
#  Trainable params: 27,939 (109.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
history
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.3288 - loss: 1.1032 - val_accuracy: 0.3452 - val_loss: 1.0977
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3524 - loss: 1.0969 - val_accuracy: 0.2893 - val_loss: 1.0980
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3560 - loss: 1.0937 - val_accuracy: 0.4365 - val_loss: 1.0833
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3850 - loss: 1.0811 - val_accuracy: 0.4873 - val_loss: 1.0685
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4044 - loss: 1.0746 - val_accuracy: 0.4569 - val_loss: 1.0614
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.4505 - loss: 1.0529 - val_accuracy: 0.4365 - val_loss: 1.0548
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4226 - loss: 1.0411 - val_accuracy: 0.4467 - val_loss: 1.0018
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4744 - loss: 1.0166 - val_accuracy: 0.4873 - val_loss: 1.0199
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4422 - loss: 1.0268 - val_accuracy: 0.4061 - val_loss: 1.0546
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4616 - loss: 1.0149 - val_accuracy: 0.4924 - val_loss: 1.0155
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4944 - loss: 1.0198 - val_accuracy: 0.4924 - val_loss: 0.9956
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.4988 - loss: 1.0016 - val_accuracy: 0.4772 - val_loss: 1.0020
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5173 - loss: 0.9913 - val_accuracy: 0.5482 - val_loss: 0.9708
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5009 - loss: 0.9821 - val_accuracy: 0.5279 - val_loss: 0.9538
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5583 - loss: 0.9515 - val_accuracy: 0.5533 - val_loss: 0.9333
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5477 - loss: 0.9346 - val_accuracy: 0.5330 - val_loss: 0.9341
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5379 - loss: 0.9296 - val_accuracy: 0.5381 - val_loss: 0.9156
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5587 - loss: 0.9189 - val_accuracy: 0.5584 - val_loss: 0.9036
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5607 - loss: 0.9167 - val_accuracy: 0.5787 - val_loss: 0.8901
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5666 - loss: 0.9022 - val_accuracy: 0.5685 - val_loss: 0.8946
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5641 - loss: 0.8977 - val_accuracy: 0.5787 - val_loss: 0.8756
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5694 - loss: 0.8774 - val_accuracy: 0.5584 - val_loss: 0.8812
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5677 - loss: 0.8822 - val_accuracy: 0.5685 - val_loss: 0.8832
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6105 - loss: 0.8460 - val_accuracy: 0.5888 - val_loss: 0.8783
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5680 - loss: 0.9017 - val_accuracy: 0.5381 - val_loss: 0.9401
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5739 - loss: 0.8914 - val_accuracy: 0.5787 - val_loss: 0.8561
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5959 - loss: 0.8370 - val_accuracy: 0.6091 - val_loss: 0.8697
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5989 - loss: 0.8441 - val_accuracy: 0.5888 - val_loss: 0.8524
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6226 - loss: 0.8419 - val_accuracy: 0.5990 - val_loss: 0.8562
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6003 - loss: 0.8232 - val_accuracy: 0.5787 - val_loss: 0.8728
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6208 - loss: 0.8388 - val_accuracy: 0.5431 - val_loss: 0.9556
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6262 - loss: 0.8124 - val_accuracy: 0.5685 - val_loss: 0.8865
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6445 - loss: 0.8169 - val_accuracy: 0.6041 - val_loss: 0.8491
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6158 - loss: 0.8142 - val_accuracy: 0.5736 - val_loss: 0.8749
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5986 - loss: 0.8042 - val_accuracy: 0.6193 - val_loss: 0.8487
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6108 - loss: 0.7893 - val_accuracy: 0.5939 - val_loss: 0.8160
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6720 - loss: 0.7685 - val_accuracy: 0.6041 - val_loss: 0.8260
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6424 - loss: 0.7631 - val_accuracy: 0.6091 - val_loss: 0.8330
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6491 - loss: 0.7510 - val_accuracy: 0.6396 - val_loss: 0.7941
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6442 - loss: 0.7751 - val_accuracy: 0.5888 - val_loss: 0.8377
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6222 - loss: 0.7837 - val_accuracy: 0.6244 - val_loss: 0.8271
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6573 - loss: 0.7561 - val_accuracy: 0.6294 - val_loss: 0.7900
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6780 - loss: 0.7157 - val_accuracy: 0.6244 - val_loss: 0.8068
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6527 - loss: 0.7724 - val_accuracy: 0.6041 - val_loss: 0.8126
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6557 - loss: 0.7112 - val_accuracy: 0.6244 - val_loss: 0.7959
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6602 - loss: 0.7418 - val_accuracy: 0.6294 - val_loss: 0.7871
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6528 - loss: 0.7286 - val_accuracy: 0.6193 - val_loss: 0.8222
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6568 - loss: 0.7507 - val_accuracy: 0.6396 - val_loss: 0.8172
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6587 - loss: 0.7737 - val_accuracy: 0.6396 - val_loss: 0.7728
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7051 - loss: 0.7141 - val_accuracy: 0.6244 - val_loss: 0.8073

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
