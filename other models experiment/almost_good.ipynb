# %%
# %pip install tensorflow
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install pydot

# %%
from PIL import Image
from pathlib import Path
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg", ".jpeg", ".bmp"]


def is_valid_image_pillow(file_name):
    try:
        with Image.open(file_name) as img:
            img.verify()
            if not img.format.lower() in ['png', 'jpeg', 'bmp']:
                print(f"{file_name} is a {img.format}, not accepted by TensorFlow")
                os.remove(file_name)

    except (IOError, SyntaxError) as e:
        print(f"{file_name} is not an image")


for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        is_valid_image_pillow(filepath)
    else:
        print(f"{filepath} not in target extensions")
# Out:
# hair_types\Curly_Hair not in target extensions
# hair_types\Straight_Hair not in target extensions
# hair_types\Wavy_Hair not in target extensions
# hair_types\Curly_Hair\rs_1080x1080-200330130638-1080-ariana-grande-curly-hair-instagram-am-033020.gif not in target extensions

# %%
curly_hair_pics = [label for label in Path(data_dir).rglob("Curly_Hair/*")]
straight_hair_pics = [label for label in Path(
    data_dir).rglob("Straight_Hair/*")]
wavy_hair_pics = [label for label in Path(data_dir).rglob("Wavy_Hair/*")]

# %%
import matplotlib.pyplot as plt
from PIL import Image

img1 = Image.open(str(curly_hair_pics[0]))
img2 = Image.open(str(straight_hair_pics[0]))
img3 = Image.open(str(wavy_hair_pics[0]))

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Curly Hair')

plt.subplot(1, 3, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Straight Hair')

plt.subplot(1, 3, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Wavy Hair')

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (256, 256)
batch_size = 64

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])


def augment_images(image, label):
    image = data_augmentation(image)
    return image, label


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical',
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
)
# Out:
# Found 987 files belonging to 3 classes.
# Using 790 files for training.
# Found 987 files belonging to 3 classes.
# Using 197 files for validation.

# %%
hair_types_labels = [label.replace("_", " ") for label in train_ds.class_names]

# %%
def apply_sobel_edges(images):
    grayscale_images = tf.image.rgb_to_grayscale(images)

    sobel_edges = tf.image.sobel_edges(grayscale_images)
    sobel_edges = tf.sqrt(tf.reduce_sum(tf.square(sobel_edges), axis=-1))

    return sobel_edges


def preprocessing(image, label):
    image = apply_sobel_edges(image)
    image = tf.tile(image, [1, 1, 1, 3])

    return image, label


train_ds = train_ds.map(preprocessing)
val_ds = val_ds.map(preprocessing)

# %%
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(hair_types_labels[int(np.argmax(labels[i]))])
        plt.axis("off")
plt.show()

# %%
from keras.models import Sequential

model = Sequential()
model.add(keras.Input(shape=image_size + (3,)))
model.add(layers.Rescaling(1.0/255))

model.add(layers.Conv2D(filters=16, kernel_size=16,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=32, kernel_size=8,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(32))
model.add(layers.Dropout(0.5))
model.add(layers.Activation("relu"))

model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))

# change back to 64 batch and size and remove the 2 dropout layers after the 2 batch normalization to get the previous results
# tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 121, 121, 16)   │        12,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 121, 121, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 121, 121, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 27, 27, 32)     │        32,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 27, 27, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 27, 27, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 5, 5, 64)       │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 1, 1, 64)       │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 1, 1, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,419 (571.95 KB)
#  Trainable params: 146,067 (570.57 KB)
#  Non-trainable params: 352 (1.38 KB)

# %%
epochs = 75

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
history
# Out:
# Epoch 1/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 635ms/step - accuracy: 0.3902 - loss: 1.6894 - val_accuracy: 0.3096 - val_loss: 1.1025
# Epoch 2/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 606ms/step - accuracy: 0.3589 - loss: 1.5767 - val_accuracy: 0.3147 - val_loss: 1.1043
# Epoch 3/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 606ms/step - accuracy: 0.4002 - loss: 1.5031 - val_accuracy: 0.3756 - val_loss: 1.1075
# Epoch 4/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 606ms/step - accuracy: 0.3815 - loss: 1.4988 - val_accuracy: 0.3452 - val_loss: 1.1134
# Epoch 5/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 793ms/step - accuracy: 0.3838 - loss: 1.5015 - val_accuracy: 0.3807 - val_loss: 1.1196
# Epoch 6/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 798ms/step - accuracy: 0.4297 - loss: 1.3644 - val_accuracy: 0.3756 - val_loss: 1.1303
# Epoch 7/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 800ms/step - accuracy: 0.3963 - loss: 1.3969 - val_accuracy: 0.3706 - val_loss: 1.1456
# Epoch 8/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 605ms/step - accuracy: 0.4106 - loss: 1.3868 - val_accuracy: 0.3909 - val_loss: 1.1615
# Epoch 9/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 650ms/step - accuracy: 0.4394 - loss: 1.3038 - val_accuracy: 0.3655 - val_loss: 1.1856
# Epoch 10/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 830ms/step - accuracy: 0.4302 - loss: 1.3619 - val_accuracy: 0.3655 - val_loss: 1.1988
# Epoch 11/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 624ms/step - accuracy: 0.4434 - loss: 1.3475 - val_accuracy: 0.3655 - val_loss: 1.2144
# Epoch 12/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 624ms/step - accuracy: 0.4189 - loss: 1.3303 - val_accuracy: 0.3706 - val_loss: 1.2177
# Epoch 13/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 608ms/step - accuracy: 0.4395 - loss: 1.3272 - val_accuracy: 0.3858 - val_loss: 1.2143
# Epoch 14/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 652ms/step - accuracy: 0.4347 - loss: 1.2500 - val_accuracy: 0.3909 - val_loss: 1.2359
# Epoch 15/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.4449 - loss: 1.2560 - val_accuracy: 0.4162 - val_loss: 1.2562
# Epoch 16/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 622ms/step - accuracy: 0.4395 - loss: 1.2744 - val_accuracy: 0.4112 - val_loss: 1.2859
# Epoch 17/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 633ms/step - accuracy: 0.4651 - loss: 1.2121 - val_accuracy: 0.4213 - val_loss: 1.3114
# Epoch 18/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 628ms/step - accuracy: 0.4304 - loss: 1.2509 - val_accuracy: 0.4010 - val_loss: 1.3170
# Epoch 19/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 623ms/step - accuracy: 0.4500 - loss: 1.1897 - val_accuracy: 0.3959 - val_loss: 1.3265
# Epoch 20/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 635ms/step - accuracy: 0.4505 - loss: 1.2073 - val_accuracy: 0.4112 - val_loss: 1.3155
# Epoch 21/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 619ms/step - accuracy: 0.4711 - loss: 1.2165 - val_accuracy: 0.4112 - val_loss: 1.3236
# Epoch 22/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 617ms/step - accuracy: 0.5009 - loss: 1.1682 - val_accuracy: 0.4264 - val_loss: 1.3151
# Epoch 23/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 615ms/step - accuracy: 0.4503 - loss: 1.2056 - val_accuracy: 0.4264 - val_loss: 1.2984
# Epoch 24/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 680ms/step - accuracy: 0.4840 - loss: 1.1975 - val_accuracy: 0.4315 - val_loss: 1.2834
# Epoch 25/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 683ms/step - accuracy: 0.4655 - loss: 1.1798 - val_accuracy: 0.4162 - val_loss: 1.2838
# Epoch 26/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 694ms/step - accuracy: 0.4642 - loss: 1.2490 - val_accuracy: 0.4264 - val_loss: 1.2927
# Epoch 27/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 663ms/step - accuracy: 0.4883 - loss: 1.1550 - val_accuracy: 0.4213 - val_loss: 1.2727
# Epoch 28/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 657ms/step - accuracy: 0.5509 - loss: 1.0275 - val_accuracy: 0.4315 - val_loss: 1.2558
# Epoch 29/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 631ms/step - accuracy: 0.5437 - loss: 1.0390 - val_accuracy: 0.4416 - val_loss: 1.2422
# Epoch 30/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 659ms/step - accuracy: 0.5294 - loss: 1.0515 - val_accuracy: 0.4721 - val_loss: 1.2346
# Epoch 31/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 652ms/step - accuracy: 0.5205 - loss: 1.0239 - val_accuracy: 0.4924 - val_loss: 1.2079
# Epoch 32/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 713ms/step - accuracy: 0.5078 - loss: 1.1089 - val_accuracy: 0.4772 - val_loss: 1.1935
# Epoch 33/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 700ms/step - accuracy: 0.5066 - loss: 1.0978 - val_accuracy: 0.4873 - val_loss: 1.1779
# Epoch 34/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 669ms/step - accuracy: 0.4891 - loss: 1.0909 - val_accuracy: 0.4924 - val_loss: 1.1627
# Epoch 35/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 658ms/step - accuracy: 0.4865 - loss: 1.1197 - val_accuracy: 0.4873 - val_loss: 1.1554
# Epoch 36/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 656ms/step - accuracy: 0.4839 - loss: 1.0517 - val_accuracy: 0.4772 - val_loss: 1.1499
# Epoch 37/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 724ms/step - accuracy: 0.4800 - loss: 1.1055 - val_accuracy: 0.5025 - val_loss: 1.1598
# Epoch 38/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 704ms/step - accuracy: 0.5066 - loss: 1.0972 - val_accuracy: 0.5127 - val_loss: 1.1580
# Epoch 39/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 702ms/step - accuracy: 0.5170 - loss: 1.0841 - val_accuracy: 0.5178 - val_loss: 1.1258
# Epoch 40/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.4827 - loss: 1.0978 - val_accuracy: 0.5381 - val_loss: 1.0947
# Epoch 41/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 683ms/step - accuracy: 0.5391 - loss: 1.0048 - val_accuracy: 0.5635 - val_loss: 1.0592
# Epoch 42/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 705ms/step - accuracy: 0.5401 - loss: 0.9472 - val_accuracy: 0.5584 - val_loss: 1.0718
# Epoch 43/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 688ms/step - accuracy: 0.5407 - loss: 1.0154 - val_accuracy: 0.5635 - val_loss: 1.0522
# Epoch 44/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 714ms/step - accuracy: 0.5581 - loss: 1.0187 - val_accuracy: 0.5431 - val_loss: 1.0588
# Epoch 45/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 752ms/step - accuracy: 0.5784 - loss: 0.9576 - val_accuracy: 0.5431 - val_loss: 1.0558
# Epoch 46/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 738ms/step - accuracy: 0.5907 - loss: 0.9384 - val_accuracy: 0.5685 - val_loss: 1.0443
# Epoch 47/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 729ms/step - accuracy: 0.5031 - loss: 1.0257 - val_accuracy: 0.5685 - val_loss: 1.0487
# Epoch 48/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 719ms/step - accuracy: 0.5646 - loss: 0.9335 - val_accuracy: 0.5635 - val_loss: 1.0635
# Epoch 49/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 691ms/step - accuracy: 0.5890 - loss: 0.9586 - val_accuracy: 0.5482 - val_loss: 1.0525
# Epoch 50/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 744ms/step - accuracy: 0.5881 - loss: 0.9004 - val_accuracy: 0.5533 - val_loss: 1.0469
# Epoch 51/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 686ms/step - accuracy: 0.5793 - loss: 0.9245 - val_accuracy: 0.5533 - val_loss: 1.0358
# Epoch 52/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 683ms/step - accuracy: 0.5633 - loss: 0.9184 - val_accuracy: 0.5533 - val_loss: 1.0320
# Epoch 53/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 663ms/step - accuracy: 0.6121 - loss: 0.8689 - val_accuracy: 0.5431 - val_loss: 1.0410
# Epoch 54/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 662ms/step - accuracy: 0.5768 - loss: 0.9328 - val_accuracy: 0.5533 - val_loss: 1.0494
# Epoch 55/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 654ms/step - accuracy: 0.5902 - loss: 0.8689 - val_accuracy: 0.5685 - val_loss: 1.0379
# Epoch 56/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 677ms/step - accuracy: 0.5776 - loss: 0.8868 - val_accuracy: 0.5584 - val_loss: 1.0409
# Epoch 57/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 618ms/step - accuracy: 0.5638 - loss: 0.9078 - val_accuracy: 0.5838 - val_loss: 1.0538
# Epoch 58/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 655ms/step - accuracy: 0.5817 - loss: 0.8821 - val_accuracy: 0.5838 - val_loss: 1.0184
# Epoch 59/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 650ms/step - accuracy: 0.5967 - loss: 0.9289 - val_accuracy: 0.5888 - val_loss: 1.0019
# Epoch 60/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 702ms/step - accuracy: 0.6103 - loss: 0.8331 - val_accuracy: 0.5838 - val_loss: 0.9991
# Epoch 61/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 711ms/step - accuracy: 0.6050 - loss: 0.8742 - val_accuracy: 0.5736 - val_loss: 0.9865
# Epoch 62/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 683ms/step - accuracy: 0.5570 - loss: 0.9090 - val_accuracy: 0.5888 - val_loss: 0.9884
# Epoch 63/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 694ms/step - accuracy: 0.6054 - loss: 0.8361 - val_accuracy: 0.5888 - val_loss: 0.9774
# Epoch 64/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 651ms/step - accuracy: 0.6133 - loss: 0.8396 - val_accuracy: 0.5787 - val_loss: 0.9854
# Epoch 65/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.6145 - loss: 0.8542 - val_accuracy: 0.5685 - val_loss: 1.0145
# Epoch 66/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 663ms/step - accuracy: 0.6169 - loss: 0.8502 - val_accuracy: 0.5533 - val_loss: 1.0114
# Epoch 67/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 636ms/step - accuracy: 0.6258 - loss: 0.8116 - val_accuracy: 0.5584 - val_loss: 0.9787
# Epoch 68/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 647ms/step - accuracy: 0.6278 - loss: 0.8337 - val_accuracy: 0.5990 - val_loss: 0.9561
# Epoch 69/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 680ms/step - accuracy: 0.6188 - loss: 0.8326 - val_accuracy: 0.5939 - val_loss: 0.9574
# Epoch 70/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 692ms/step - accuracy: 0.6256 - loss: 0.8316 - val_accuracy: 0.5838 - val_loss: 0.9581
# Epoch 71/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 630ms/step - accuracy: 0.6570 - loss: 0.7955 - val_accuracy: 0.5736 - val_loss: 0.9669
# Epoch 72/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 665ms/step - accuracy: 0.6566 - loss: 0.7957 - val_accuracy: 0.5736 - val_loss: 0.9596
# Epoch 73/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 670ms/step - accuracy: 0.6155 - loss: 0.8151 - val_accuracy: 0.5888 - val_loss: 0.9643
# Epoch 74/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 678ms/step - accuracy: 0.6309 - loss: 0.7769 - val_accuracy: 0.5787 - val_loss: 0.9479
# Epoch 75/75
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 715ms/step - accuracy: 0.6529 - loss: 0.7744 - val_accuracy: 0.5685 - val_loss: 0.9487

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np

true_labels = []
pred_labels = []

for images, labels in val_ds:
    true_labels.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images)
    pred_labels.extend(np.argmax(preds, axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

hair_labels_cm = ['Curly Hair', 'Straight Hair', 'Wavy Hair']

cm = confusion_matrix(true_labels, pred_labels)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=hair_labels_cm).plot(
    include_values=True, cmap='Blues', colorbar=False)

# %%
from sklearn.metrics import classification_report
import pandas as pd

class_report = classification_report(
    true_labels, pred_labels, target_names=hair_types_labels, output_dict=True)
report_df = pd.DataFrame(class_report).transpose()

report_df = report_df.drop(index=['accuracy', 'macro avg', 'weighted avg'])
report_df = report_df.round(2)

report_df
# Out:
#                precision  recall  f1-score  support
# Curly Hair          0.62    0.70      0.66     56.0
# Straight Hair       0.61    0.40      0.48     70.0
# Wavy Hair           0.51    0.63      0.57     71.0

# %%
img_array = keras.preprocessing.image.img_to_array(img3)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)

plt.axis("off")
plt.imshow(img3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# This image is 0.53 percent curly hair, 0.03 percent straight hair, and 0.44 percent wavy hair.
