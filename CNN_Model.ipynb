# %%
# %pip install tensorflow
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install pydot

# %%
from PIL import Image
from pathlib import Path
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg", ".jpeg", ".bmp"]


def is_valid_image_pillow(file_name):
    try:
        with Image.open(file_name) as img:
            img.verify()
            if not img.format.lower() in ['png', 'jpeg', 'bmp']:
                print(f"{file_name} is a {img.format}, not accepted by TensorFlow")
                os.remove(file_name)

    except (IOError, SyntaxError) as e:
        print(f"{file_name} is not an image")


for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        is_valid_image_pillow(filepath)
    else:
        print(f"{filepath} not in target extensions")
# Out:
# hair_types\Curly_Hair not in target extensions
# hair_types\Straight_Hair not in target extensions
# hair_types\Wavy_Hair not in target extensions
# hair_types\Curly_Hair\rs_1080x1080-200330130638-1080-ariana-grande-curly-hair-instagram-am-033020.gif not in target extensions

# %%
curly_hair_pics = [label for label in Path(data_dir).rglob("Curly_Hair/*")]
straight_hair_pics = [label for label in Path(
    data_dir).rglob("Straight_Hair/*")]
wavy_hair_pics = [label for label in Path(data_dir).rglob("Wavy_Hair/*")]

# %%
import matplotlib.pyplot as plt
from PIL import Image

img1 = Image.open(str(curly_hair_pics[0]))
img2 = Image.open(str(straight_hair_pics[0]))
img3 = Image.open(str(wavy_hair_pics[0]))

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img1)
plt.axis('off')
plt.title('Curly Hair')

plt.subplot(1, 3, 2)
plt.imshow(img2)
plt.axis('off')
plt.title('Straight Hair')

plt.subplot(1, 3, 3)
plt.imshow(img3)
plt.axis('off')
plt.title('Wavy Hair')

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

image_size = (256, 256)
batch_size = 64

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])


def augment_images(image, label):
    image = data_augmentation(image)
    return image, label


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical',
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types/",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels='inferred',
    label_mode='categorical'
    # ).map(augment_images)
)
# Out:
# Found 984 files belonging to 3 classes.
# Using 788 files for training.
# Found 984 files belonging to 3 classes.
# Using 196 files for validation.

# %%
hair_types_labels = [label.replace("_", " ") for label in train_ds.class_names]

# %%
def apply_sobel_edges(images):
    sobel_edges = tf.image.sobel_edges(images)
    sobel_edges = tf.sqrt(tf.reduce_sum(tf.square(sobel_edges), axis=-1))

    return sobel_edges


def preprocessing(image, label):
    image = apply_sobel_edges(image)

    return image, label


train_ds = train_ds.map(preprocessing)
val_ds = val_ds.map(preprocessing)

# %%
import numpy as np

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(hair_types_labels[int(np.argmax(labels[i]))])
        plt.axis("off")
plt.show()

# %%
from keras.models import Sequential

model = Sequential()
model.add(keras.Input(shape=image_size + (3,)))
model.add(layers.Rescaling(1.0/255))

model.add(layers.Conv2D(filters=16, kernel_size=16,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=32, kernel_size=8,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D(2, 2))
model.add(layers.Dropout(0.25))

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(filters=64, kernel_size=4,
          strides=2, padding='valid', dilation_rate=1))
model.add(layers.Activation('relu'))
model.add(layers.BatchNormalization())

model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())

model.add(layers.Dense(32))
model.add(layers.Dropout(0.5))
model.add(layers.Activation("relu"))

model.add(layers.Dense(3))
model.add(layers.Activation("softmax"))


# tf.keras.utils.plot_model(model, to_file='model_test.png', show_shapes=True)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

model.summary()
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_9 (Rescaling)         │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 121, 121, 16)   │        12,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_54 (Activation)      │ (None, 121, 121, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 121, 121, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 60, 60, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 27, 27, 32)     │        32,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_55 (Activation)      │ (None, 27, 27, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 27, 27, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 5, 5, 64)       │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_56 (Activation)      │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 1, 1, 64)       │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_57 (Activation)      │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 1, 1, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_9      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_58 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 3)              │            99 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_59 (Activation)      │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,419 (571.95 KB)
#  Trainable params: 146,067 (570.57 KB)
#  Non-trainable params: 352 (1.38 KB)

# %%
epochs = 50

history = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
history
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.3412 - loss: 1.8371 - val_accuracy: 0.3367 - val_loss: 1.0963
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 667ms/step - accuracy: 0.3381 - loss: 1.8028 - val_accuracy: 0.3724 - val_loss: 1.1012
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 654ms/step - accuracy: 0.3962 - loss: 1.5925 - val_accuracy: 0.4133 - val_loss: 1.0949
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 679ms/step - accuracy: 0.3615 - loss: 1.7575 - val_accuracy: 0.4337 - val_loss: 1.0874
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 705ms/step - accuracy: 0.3544 - loss: 1.7271 - val_accuracy: 0.3980 - val_loss: 1.0872
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 704ms/step - accuracy: 0.3806 - loss: 1.5533 - val_accuracy: 0.3827 - val_loss: 1.0935
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 714ms/step - accuracy: 0.4107 - loss: 1.4956 - val_accuracy: 0.3827 - val_loss: 1.0995
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 729ms/step - accuracy: 0.4153 - loss: 1.5303 - val_accuracy: 0.3827 - val_loss: 1.1083
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 720ms/step - accuracy: 0.4158 - loss: 1.3825 - val_accuracy: 0.3929 - val_loss: 1.1235
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 712ms/step - accuracy: 0.4427 - loss: 1.3355 - val_accuracy: 0.3929 - val_loss: 1.1386
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 715ms/step - accuracy: 0.4501 - loss: 1.3862 - val_accuracy: 0.3827 - val_loss: 1.1606
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 729ms/step - accuracy: 0.4119 - loss: 1.3060 - val_accuracy: 0.3980 - val_loss: 1.1734
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 735ms/step - accuracy: 0.4454 - loss: 1.3008 - val_accuracy: 0.3929 - val_loss: 1.1698
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 684ms/step - accuracy: 0.4537 - loss: 1.2808 - val_accuracy: 0.4286 - val_loss: 1.1851
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 701ms/step - accuracy: 0.4613 - loss: 1.2671 - val_accuracy: 0.4337 - val_loss: 1.1896
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 719ms/step - accuracy: 0.4696 - loss: 1.2765 - val_accuracy: 0.4286 - val_loss: 1.1908
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 701ms/step - accuracy: 0.4749 - loss: 1.2092 - val_accuracy: 0.4235 - val_loss: 1.1965
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 675ms/step - accuracy: 0.5020 - loss: 1.1657 - val_accuracy: 0.4337 - val_loss: 1.2038
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 717ms/step - accuracy: 0.4670 - loss: 1.2948 - val_accuracy: 0.4388 - val_loss: 1.2505
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 621ms/step - accuracy: 0.4774 - loss: 1.2153 - val_accuracy: 0.4388 - val_loss: 1.2510
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 658ms/step - accuracy: 0.5114 - loss: 1.1348 - val_accuracy: 0.4694 - val_loss: 1.2439
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 684ms/step - accuracy: 0.5171 - loss: 1.1059 - val_accuracy: 0.4745 - val_loss: 1.2549
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 638ms/step - accuracy: 0.5084 - loss: 1.1620 - val_accuracy: 0.4796 - val_loss: 1.2590
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 663ms/step - accuracy: 0.4994 - loss: 1.1339 - val_accuracy: 0.4643 - val_loss: 1.2311
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 705ms/step - accuracy: 0.5001 - loss: 1.0938 - val_accuracy: 0.4847 - val_loss: 1.2289
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 716ms/step - accuracy: 0.4995 - loss: 1.0826 - val_accuracy: 0.4796 - val_loss: 1.2119
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 676ms/step - accuracy: 0.5375 - loss: 1.0263 - val_accuracy: 0.4898 - val_loss: 1.1912
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 652ms/step - accuracy: 0.4817 - loss: 1.1494 - val_accuracy: 0.4745 - val_loss: 1.1598
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 637ms/step - accuracy: 0.5138 - loss: 1.0717 - val_accuracy: 0.4949 - val_loss: 1.1588
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 640ms/step - accuracy: 0.5225 - loss: 1.0436 - val_accuracy: 0.5153 - val_loss: 1.1543
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 624ms/step - accuracy: 0.5282 - loss: 1.0062 - val_accuracy: 0.5000 - val_loss: 1.1576
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 623ms/step - accuracy: 0.5260 - loss: 0.9909 - val_accuracy: 0.5102 - val_loss: 1.1537
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 662ms/step - accuracy: 0.5425 - loss: 0.9870 - val_accuracy: 0.5051 - val_loss: 1.1560
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 653ms/step - accuracy: 0.5386 - loss: 0.9931 - val_accuracy: 0.5204 - val_loss: 1.1621
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 672ms/step - accuracy: 0.5884 - loss: 0.9305 - val_accuracy: 0.5153 - val_loss: 1.1640
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 677ms/step - accuracy: 0.5683 - loss: 1.0038 - val_accuracy: 0.5408 - val_loss: 1.1519
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 685ms/step - accuracy: 0.5539 - loss: 0.9690 - val_accuracy: 0.5561 - val_loss: 1.1301
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 682ms/step - accuracy: 0.5456 - loss: 0.9598 - val_accuracy: 0.5204 - val_loss: 1.1236
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 687ms/step - accuracy: 0.5498 - loss: 0.9648 - val_accuracy: 0.5459 - val_loss: 1.1183
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 684ms/step - accuracy: 0.5886 - loss: 0.8782 - val_accuracy: 0.5306 - val_loss: 1.1109
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 709ms/step - accuracy: 0.6314 - loss: 0.8755 - val_accuracy: 0.5204 - val_loss: 1.0748
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 643ms/step - accuracy: 0.5794 - loss: 0.8597 - val_accuracy: 0.5561 - val_loss: 1.0315
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 629ms/step - accuracy: 0.5884 - loss: 0.8862 - val_accuracy: 0.5663 - val_loss: 0.9977
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 648ms/step - accuracy: 0.5678 - loss: 0.9035 - val_accuracy: 0.5816 - val_loss: 0.9867
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 682ms/step - accuracy: 0.6422 - loss: 0.7984 - val_accuracy: 0.5663 - val_loss: 1.0035
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 681ms/step - accuracy: 0.6195 - loss: 0.8187 - val_accuracy: 0.5918 - val_loss: 0.9985
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 672ms/step - accuracy: 0.6241 - loss: 0.8026 - val_accuracy: 0.5918 - val_loss: 0.9722
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 659ms/step - accuracy: 0.6197 - loss: 0.8163 - val_accuracy: 0.5867 - val_loss: 0.9775
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 667ms/step - accuracy: 0.6430 - loss: 0.8029 - val_accuracy: 0.5918 - val_loss: 0.9975
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 671ms/step - accuracy: 0.6145 - loss: 0.8398 - val_accuracy: 0.5867 - val_loss: 1.0101

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np

true_labels = []
pred_labels = []

for images, labels in val_ds:
    true_labels.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images)
    pred_labels.extend(np.argmax(preds, axis=1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

hair_labels_cm = ['Curly Hair', 'Straight Hair', 'Wavy Hair']

cm = confusion_matrix(true_labels, pred_labels)
ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=hair_labels_cm).plot(
    include_values=True, cmap='Blues', colorbar=False)

# %%
from sklearn.metrics import classification_report
import pandas as pd

class_report = classification_report(
    true_labels, pred_labels, target_names=hair_types_labels, output_dict=True)
report_df = pd.DataFrame(class_report).transpose()

report_df = report_df.drop(index=['accuracy', 'macro avg', 'weighted avg'])
report_df = report_df.round(2)

report_df
# Out:
#                precision  recall  f1-score  support
# Curly Hair          0.61    0.77      0.68     56.0
# Straight Hair       0.70    0.30      0.42     69.0
# Wavy Hair           0.53    0.72      0.61     71.0

# %%
img_array = keras.preprocessing.image.img_to_array(img3)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)

plt.axis("off")
plt.imshow(img3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# This image is 0.33 percent curly hair, 0.04 percent straight hair, and 0.63 percent wavy hair.
